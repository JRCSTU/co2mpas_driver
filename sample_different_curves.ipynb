# %% [markdown]
# # How to extract the acceleration curves of a vehicle

# %%
import schedula as sh
from co2mpas_driver import dsp as driver
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Processing chain model

# %%
driver.plot(view=False).site(index=False)  # Click on the graph to see the model.
# Out:
#  * Serving Flask app "C:\Users\Ashenafi\AppData\Local\Temp\tmp1flc7chu" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:59729/ (Press CTRL+C to quit)
# Site(SiteMap([(Dispatcher 2162715283584, SiteMap([(load, SiteMap()), (model, SiteMap()), (plot, SiteMap())]))]), host='localhost', port=0, depth=-1, index=False, root_path=None)
# 127.0.0.1 - - [04/Sep/2019 16:06:15] "GET / HTTP/1.1" 200 -

# %%
driver.get_node('model')[0].plot(view=False).site(index=False)  # Click on the graph to see the model.
# Out:
#  * Serving Flask app "C:\Users\Ashenafi\AppData\Local\Temp\tmptzwh9go9" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:59739/ (Press CTRL+C to quit)
# Site(SiteMap([(model, SiteMap())]), host='localhost', port=0, depth=-1, index=False, root_path=None)
# 127.0.0.1 - - [04/Sep/2019 16:06:41] "GET / HTTP/1.1" 200 -

# %%
sol = driver(dict(vehicle_id=39393, inputs=dict(inputs={'gear_shifting_style': 0.8, 'degree': 2})))
iplot(sol['outputs']['discrete_acceleration_curves'])
# Out:
# <div>
#
#
#             <div id="81edb96f-8f31-415d-9383-eb12a9b70d32" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("81edb96f-8f31-415d-9383-eb12a9b70d32")) {
#                     Plotly.newPlot(
#                         '81edb96f-8f31-415d-9383-eb12a9b70d32',
#                         [{"type": "scatter", "uid": "83fdd91f-b7de-4906-9fba-14fa823f33b3", "x": [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6000000000000001, 0.7000000000000001, 0.8, 0.9, 1.0, 1.1, 1.2000000000000002, 1.3, 1.4000000000000001, 1.5, 1.6, 1.7000000000000002, 1.8, 1.9000000000000001, 2.0, 2.1, 2.2, 2.3000000000000003, 2.4000000000000004, 2.5, 2.6, 2.7, 2.8000000000000003, 2.9000000000000004, 3.0, 3.1, 3.2, 3.3000000000000003, 3.4000000000000004, 3.5, 3.6, 3.7, 3.8000000000000003, 3.9000000000000004, 4.0, 4.1000000000000005, 4.2, 4.3, 4.4, 4.5, 4.6000000000000005, 4.7, 4.800000000000001, 4.9, 5.0, 5.1000000000000005, 5.2, 5.300000000000001, 5.4, 5.5, 5.6000000000000005, 5.7, 5.800000000000001, 5.9, 6.0, 6.1000000000000005, 6.2, 6.300000000000001, 6.4, 6.5, 6.6000000000000005, 6.7, 6.800000000000001, 6.9, 7.0, 7.1000000000000005, 7.2, 7.300000000000001, 7.4, 7.5, 7.6000000000000005, 7.7, 7.800000000000001, 7.9, 8.0, 8.1, 8.200000000000001, 8.3, 8.4, 8.5, 8.6, 8.700000000000001, 8.8, 8.9, 9.0, 9.1, 9.200000000000001, 9.3, 9.4, 9.5, 9.600000000000001, 9.700000000000001], "y": [4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411]}, {"type": "scatter", "uid": "b8725148-831b-46af-baac-db2ee9a149a8", "x": [4.430869020968256, 4.530869020968256, 4.630869020968255, 4.730869020968255, 4.8308690209682545, 4.930869020968254, 5.030869020968254, 5.1308690209682535, 5.230869020968253, 5.330869020968253, 5.430869020968252, 5.530869020968252, 5.630869020968252, 5.730869020968251, 5.830869020968251, 5.930869020968251, 6.03086902096825, 6.13086902096825, 6.23086902096825, 6.330869020968249, 6.430869020968249, 6.5308690209682485, 6.630869020968248, 6.730869020968248, 6.830869020968247, 6.930869020968247, 7.030869020968247, 7.130869020968246, 7.230869020968246, 7.330869020968246, 7.430869020968245, 7.530869020968245, 7.630869020968245, 7.730869020968244, 7.830869020968244, 7.9308690209682435, 8.030869020968243, 8.130869020968243, 8.230869020968242, 8.330869020968242, 8.430869020968242, 8.530869020968241, 8.630869020968241, 8.73086902096824, 8.83086902096824, 8.93086902096824, 9.03086902096824, 9.13086902096824, 9.230869020968239, 9.330869020968239, 9.430869 ...
