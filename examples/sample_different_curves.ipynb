# %% [markdown]
# # How to extract the acceleration curves of a vehicle

# %% [markdown]
# This is an ipython notebook to present how to use the co2mpas driver model (i.e., MFC) to simulate the driver behaviour on an electric vehicle.

# %% [markdown]
# # Import co2mpas driver model and other libraries

# %%
import sys;
sys.path.extend(['..'])
import schedula as sh
from plotly import graph_objs as go
from co2mpas_driver import dsp as driver
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Processing chain model

# %%
driver.plot(view=False).site(index=False)  # Click on the graph to see the model.
# Out:
#  * Serving Flask app "C:\Users\makieas\AppData\Local\Temp\tmpp7dl744l" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:58735/ (Press CTRL+C to quit)
# Site(SiteMap([(Dispatcher 2556454478792, SiteMap([(load, SiteMap()), (model, SiteMap()), (plot, SiteMap())]))]), host='localhost', port=0, depth=-1, index=False, root_path=None)

# %% [markdown]
# # Plot co2mpas driver model graph

# %%
driver.get_node('model')[0].plot(view=False).site(index=False)  # Click on the graph to see the model.
# Out:
#  * Serving Flask app "C:\Users\makieas\AppData\Local\Temp\tmp2ixizds2" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:58742/ (Press CTRL+C to quit)
# Site(SiteMap([(model, SiteMap())]), host='localhost', port=0, depth=-1, index=False, root_path=None)

# %% [markdown]
# # user inputs (chose unique vehicle, gear_shifting_style, degree etc) to co2mpas driver model in order to extract the drivers acceleration behavior as approaching the desired velocity

# %%
# Remember to Insert vehicle data base path (db_path)
car_id = 39393
db_path='../co2mpas_driver/db/EuroSegmentCar_cleaned.csv'
sol = driver(dict(vehicle_id=car_id, inputs=dict(inputs=dict(gear_shifting_style=0.8, degree=2, 
                                                             use_linear_gs=True, use_cubic=False))))
sol.plot(view=False).site(index=False)
# Out:
#  * Serving Flask app "C:\Users\makieas\AppData\Local\Temp\tmp0no3iugd" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:58747/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Feb/2020 14:34:45] "GET / HTTP/1.1" 200 -
# Site(SiteMap([(Dispatcher 2556454478792, SiteMap([(load, SiteMap()), (model, SiteMap()), (plot, SiteMap())]))]), host='localhost', port=0, depth=-1, index=False, root_path=None)

# %%
list(driver.get_node('model')[0].dsp.data_nodes)
# Out:
# ['ignition_type',
#  'full_load_curve',
#  'engine_max_power',
#  'engine_max_speed_at_max_power',
#  'idle_engine_speed',
#  'full_load_speeds',
#  'full_load_powers',
#  'full_load_torques',
#  'gear_box_ratios',
#  'tyre_radius',
#  'driveline_slippage',
#  'final_drive_ratio',
#  'driveline_efficiency',
#  'vehicle_mass',
#  'speed_per_gear',
#  'acc_per_gear',
#  'degree',
#  'coefs_per_gear',
#  'motor_max_power',
#  'fuel_type',
#  'motor_max_torque',
#  'vehicle_max_speed',
#  'poly_spline',
#  'start',
#  'stop',
#  'use_cubic',
#  'sp_bins',
#  'discrete_poly_spline',
#  'speed_per_gear_updated',
#  'acc_per_gear_updated',
#  'car_res_curve_force',
#  'discrete_car_res_curve_force',
#  'car_res_curve',
#  'discrete_car_res_curve',
#  'type_of_car',
#  'car_width',
#  'car_height',
#  'car_type',
#  'Alimit',
#  'curves',
#  'curves_dec',
#  'discrete_acceleration_curves',
#  'discrete_deceleration_curves',
#  'gear_shifting_style',
#  'use_linear_gs',
#  'gs',
#  'idle_engine_speed_median',
#  'idle_engine_speed_std',
#  'tans',
#  'sim_start',
#  'duration',
#  'sim_step',
#  'times',
#  'transmission',
#  'driver_style',
#  'driver_simulation_model',
#  'starting_velocity',
#  'desired_velocity',
#  'gears',
#  'velocities',
#  'accelerations',
#  'positions',
#  'r_dynamic',
#  'gearbox_type',
#  'engine_max_torque',
#  'fuel_eng_capacity',
#  'max_power',
#  'fuel_engine_stroke',
#  'fuel_turbo',
#  'fp']

# %% [markdown]
# # Compute and plot final acceleration curve per gear

# %%
outputs = sol['outputs'] # outputs of the dispatcher
layout = go.Layout(title="Acceleration-Velocity per gear",
                xaxis=dict(title='velocity (in m/s)'),
                yaxis=dict(title='Acceleration (in m/s2'))
data = outputs['discrete_acceleration_curves']
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# 127.0.0.1 - - [24/Feb/2020 14:34:45] "GET / HTTP/1.1" 200 -
# <div>
#
#
#             <div id="e88df5f2-60a1-4b8f-b2cb-e1f5f094032b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e88df5f2-60a1-4b8f-b2cb-e1f5f094032b")) {
#                     Plotly.newPlot(
#                         'e88df5f2-60a1-4b8f-b2cb-e1f5f094032b',
#                         [{"type": "scatter", "x": [0.0, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0, 1.2000000000000002, 1.4000000000000001, 1.6, 1.8, 2.0, 2.2, 2.4000000000000004, 2.6, 2.8000000000000003, 3.0, 3.2, 3.4000000000000004, 3.6, 3.8000000000000003, 4.0, 4.2, 4.4, 4.6000000000000005, 4.800000000000001, 5.0, 5.2, 5.4, 5.6000000000000005, 5.800000000000001, 6.0, 6.2, 6.4, 6.6000000000000005, 6.800000000000001, 7.0, 7.2, 7.4, 7.6000000000000005, 7.800000000000001, 8.0, 8.200000000000001, 8.4, 8.6, 8.8, 9.0, 9.200000000000001, 9.4, 9.600000000000001, 9.8, 10.0, 10.200000000000001, 10.4, 10.600000000000001, 10.8, 11.0, 11.200000000000001], "y": [4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411]}, {"type": "scatter", "x": [5.108720641336494, 5.308720641336494, 5.508720641336494, 5.708720641336495, 5.908720641336495, 6.108720641336495, 6.308720641336495, 6.508720641336495, 6.7087206413364955, 6.908720641336496, 7.108720641336496, 7.308720641336496, 7.508720641336496, 7.708720641336496, 7.9087206413364965, 8.108720641336497, 8.308720641336496, 8.508720641336497, 8.708720641336498, 8.908720641336497, 9.108720641336497, 9.308720641336498, 9.508720641336499, 9.708720641336498, 9.908720641336497, 10.108720641336499, 10.3087206413365, 10.508720641336499, 10.708720641336498, 10.9087206413365, 11.1087206413365, 11.3087206413365, 11.508720641336499, 11.7087206413365, 11.908720641336501, 12.1087206413365, 12.3087206413365, 12.5087206413365, 12.708720641336502, 12.908720641336501, 13.1087206413365, 13.3087206413365, 13.508720641336502, 13.708720641336502, 13.908720641336501, 14.1087206413365, 14.308720641336503, 14.508720641336502, 14.708720641336502, 14.908720641336501, 15.108720641336504, 15.308720641336503, 15.508720641336502, 15.708720641336502, 15.908720641336505, 16.108720641336504, 16.308720641336503, 16.508720641336502, 16.708720641336505, 16.908720641336505, 17.108720641336504, 17.308720641336503, 17.508720641336506, 17.708720641336505, 17.908720641336505, 18.108720641336504, 18.308720641336507, 18.508720641336506, 18.708720641336505, 18.908720641336505], "y": [3.9070767357738534, 3.963334061676443, 4.017574514912047, 4.069798095480665, 4.120004803382295, 4.16819463861694, 4.214367601184599, 4.258523691085272, 4.300662908318957, 4.340785252885657, 4.3788907247853714, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.402079173607411, 4.40207917360741 ...
# 127.0.0.1 - - [24/Feb/2020 14:34:46] "GET / HTTP/1.1" 200 -
