# %% [markdown]
# # How to extract the acceleration curves of a vehicle

# %% [markdown]
# This is an ipython notebook to present how to use the co2mpas driver model (i.e., MFC) to simulate the driver behaviour on an electric vehicle.

# %% [markdown]
# # Import co2mpas driver model and other libraries

# %%
import sys;
sys.path.extend(['..'])
import schedula as sh
from plotly import graph_objs as go
from co2mpas_driver import dsp as driver
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Processing chain model

# %%
driver.plot(view=False).site(index=False)  # Click on the graph to see the model.
# Out:
#  * Serving Flask app "C:\Users\makieas\AppData\Local\Temp\tmptnmisq39" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:60262/ (Press CTRL+C to quit)
# Site(SiteMap([(Dispatcher 1652725953760, SiteMap([(load, SiteMap()), (model, SiteMap()), (plot, SiteMap())]))]), host='localhost', port=0, depth=-1, index=False, root_path=None)

# %% [markdown]
# # Plot co2mpas driver model graph

# %%
driver.get_node('model')[0].plot(view=False).site(index=False)  # Click on the graph to see the model.
# Out:
#  * Serving Flask app "C:\Users\makieas\AppData\Local\Temp\tmp4cg7x55r" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:60269/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Feb/2020 14:57:20] "GET / HTTP/1.1" 200 -
# Site(SiteMap([(model, SiteMap())]), host='localhost', port=0, depth=-1, index=False, root_path=None)

# %% [markdown]
# # User inputs to co2mpas driver model in order to extract the drivers acceleration behavior

# %%
# Remember to Insert vehicle data base path (db_path)
sol = driver(dict(vehicle_id=35135, db_path='../co2mpas_driver/db/EuroSegmentCar_cleaned.csv', inputs=dict(inputs=dict(
        gear_shifting_style=0.8, degree=4, use_linear_gs=True, use_cubic=False))))
sol.plot(view=False).site(index=False)
# Out:
#  * Serving Flask app "C:\Users\makieas\AppData\Local\Temp\tmp9expq6jl" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:60277/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Feb/2020 14:57:21] "GET / HTTP/1.1" 200 -
# Site(SiteMap([(Dispatcher 1652725953760, SiteMap([(load, SiteMap()), (model, SiteMap()), (plot, SiteMap())]))]), host='localhost', port=0, depth=-1, index=False, root_path=None)

# %%
list(driver.get_node('model')[0].dsp.data_nodes)
# Out:
# ['ignition_type',
#  'full_load_curve',
#  'engine_max_power',
#  'engine_max_speed_at_max_power',
#  'idle_engine_speed',
#  'full_load_speeds',
#  'full_load_powers',
#  'full_load_torques',
#  'gear_box_ratios',
#  'tyre_radius',
#  'driveline_slippage',
#  'final_drive_ratio',
#  'driveline_efficiency',
#  'vehicle_mass',
#  'speed_per_gear',
#  'acc_per_gear',
#  'degree',
#  'coefs_per_gear',
#  'motor_max_power',
#  'fuel_type',
#  'motor_max_torque',
#  'vehicle_max_speed',
#  'poly_spline',
#  'start',
#  'stop',
#  'use_cubic',
#  'sp_bins',
#  'discrete_poly_spline',
#  'speed_per_gear_updated',
#  'acc_per_gear_updated',
#  'car_res_curve_force',
#  'discrete_car_res_curve_force',
#  'car_res_curve',
#  'discrete_car_res_curve',
#  'type_of_car',
#  'car_width',
#  'car_height',
#  'car_type',
#  'Alimit',
#  'curves',
#  'curves_dec',
#  'discrete_acceleration_curves',
#  'discrete_deceleration_curves',
#  'gear_shifting_style',
#  'use_linear_gs',
#  'gs',
#  'idle_engine_speed_median',
#  'idle_engine_speed_std',
#  'tans',
#  'sim_start',
#  'duration',
#  'sim_step',
#  'times',
#  'transmission',
#  'driver_style',
#  'driver_simulation_model',
#  'starting_velocity',
#  'desired_velocity',
#  'gears',
#  'velocities',
#  'accelerations',
#  'positions',
#  'r_dynamic',
#  'gearbox_type',
#  'engine_max_torque',
#  'fuel_eng_capacity',
#  'max_power',
#  'fuel_engine_stroke',
#  'fuel_turbo',
#  'fp']

# %% [markdown]
# # Compute and plot final acceleration curve per gear

# %%
outputs = sol['outputs'] # outputs of the dispatcher
layout = go.Layout(title="Acceleration-Velocity per gear",
                xaxis=dict(title='velocity (in m/s)'),
                yaxis=dict(title='Acceleration (in m/s2'))
data = outputs['discrete_acceleration_curves']
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
